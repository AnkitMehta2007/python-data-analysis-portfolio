# %% [markdown]
# #**Interacting with the os and filesysytem**
#
# The os module in python many function for interacting with the os and the file system.Let's import it and try out some example.

# %%
import os

# %% [markdown]
# WE can check the present working directry using the os.getcwd function

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# To get the list of files in directry use os.listdir.you pass an absolute or relative path of a directry as the argument to the function

# %%
help(os.listdir)
# Out:
# Help on built-in function listdir in module posix:
#
# listdir(path=None)
#     Return a list containing the names of the files in the directory.
#
#     path can be specified as either str, bytes, or a path-like object.  If path is bytes,
#       the filenames returned will also be bytes; in all other circumstances
#       the filenames returned will be str.
#     If path is None, uses the path='.'.
#     On some platforms, path may also be specified as an open file descriptor;\
#       the file descriptor must refer to a directory.
#       If this functionality is unavailable, using it raises NotImplementedError.
#
#     The list is in arbitrary order.  It does not include the special
#     entries '.' and '..' even if they are present in the directory.

# %%
os.listdir('.')#relative path (.)dot shortcut  to know cureent directry
# Out:
# ['.config', 'data', 'sample_data']

# %%
os.listdir('/')#absolute path-top level rootFolder=/
# Out:
# ['opt',
#  'home',
#  'sbin',
#  'media',
#  'usr',
#  'mnt',
#  'etc',
#  'run',
#  'bin',
#  'sys',
#  'tmp',
#  'boot',
#  'root',
#  'lib',
#  'libx32',
#  'lib32',
#  'var',
#  'srv',
#  'dev',
#  'proc',
#  'lib64',
#  'content',
#  'kaggle',
#  '.dockerenv',
#  'datalab',
#  'tools',
#  'python-apt',
#  'python-apt.tar.xz']

# %%
os.listdir('/usr')
# Out:
# ['src',
#  'sbin',
#  'include',
#  'bin',
#  'lib',
#  'libx32',
#  'lib32',
#  'local',
#  'games',
#  'libexec',
#  'share',
#  'lib64',
#  'colab',
#  'etc',
#  'grte']

# %% [markdown]
# A new directry can be created using os.makedirs.Lets ctreate a new directry call data,where we'll later dounload some files

# %%
os.makedirs('./data',exist_ok=True)

# %%
help(os.makedirs('./data',exist_ok=True))
# Out:
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.

# %% [markdown]
# Lest's varify that the directry was in fact ,created ,and is currently empty.

# %%
'data' in os.listdir('.')
# Out:
# True

# %%
os.listdir('./data')
# Out:
# ['loans1.txt', 'loans2.txt', 'loans3.txt']

# %% [markdown]
# Lets us dounload some file into the data directry using the urllib module.
#
# urllib is a Python library used to work with URLs.
#
# Why it exists
# Data often lives on the internet.
#
# Used for
# • Read data from websites
# • Download files
# • Send requests

# %% [markdown]
# #WHY urllib IS IMPORTANT
#
# • Load online datasets
# • Access APIs
# • Download data automatically

# %%
url1='https://gist.githubusercontent.com/aakashns/8de7b03f241b787042be1a1e4afd91da/raw/a15ba86d0260ca2d2615afa9d809bf4be019ab3d/loans1.txt'
url2='https://gist.githubusercontent.com/aakashns/8de7b03f241b787042be1a1e4afd91da/raw/a15ba86d0260ca2d2615afa9d809bf4be019ab3d/loans2.txt'
url3='https://gist.githubusercontent.com/aakashns/8de7b03f241b787042be1a1e4afd91da/raw/a15ba86d0260ca2d2615afa9d809bf4be019ab3d/loans3.txt'

# %%
import urllib.request

# %%
import os
os.makedirs('./data',exist_ok=True)
urllib.request.urlretrieve(url1,'./data/loans1.txt')
# Out:
# ('./data/loans1.txt', <http.client.HTTPMessage at 0x7dead71bf410>)

# %%
urllib.request.urlretrieve(url2,'./data/loans2.txt')
# Out:
# ('./data/loans2.txt', <http.client.HTTPMessage at 0x7dead71bd7c0>)

# %%
urllib.request.urlretrieve(url3,'./data/loans3.txt')
# Out:
# ('./data/loans3.txt', <http.client.HTTPMessage at 0x7dead71bed20>)

# %%
os.listdir('./data')
# Out:
# ['loans1.txt', 'loans2.txt', 'loans3.txt']

# %% [markdown]
# #READING FROM A FILE

# %%
file1=open('./data/loans1.txt',mode='r')

# %%
file_content=file1.read()

# %%
print(file_content)
# Out:
# amount,duration,rate,down_payment
# 10000,36,0.08,20000
# 200000,12,0.1,
# 628400,120,0.12,100000
# 4637400,240,0.06,
# 42900,90,0.07,8900
# 916000,16,0.13,
# 45230,48,0.08,4300
# 991360,99,0.08,
# 423000,27,0.09,47200

# %% [markdown]
# The CSV is a common file format used for sharing data for analysis and visualization. Over the course of this tutorial, we will read the data from these CSV files, process it, and write the results back to files. Before we continue, let's close the file using the close method (otherwise Python will continue to hold the entire file in the RAM)

# %%
file1.close()

# %% [markdown]
# oNCE A FILE CLOSED ,IT CAN NO LONGER BE READ

# %%
#file1.read()-Give error beacuse file is already closed

# %% [markdown]
# #cLOSING FILES AUTOMATICLY USINNG WITH

# %%
with open('./data/loans2.txt','r') as file2:
  file2_content=file2.read()
  print(file2_content)
# Out:
# amount,duration,rate,down_payment
# 828400,120,0.11,100000
# 4633400,240,0.06,
# 42900,90,0.08,8900
# 983000,16,0.14,
# 15230,48,0.07,4300

# %%
#file2.read()-give error beacuse file is closed

# %% [markdown]
# #Reading Line BY line

# %%
with open('./data/loans3.txt','r') as file3:
  file3_lines=file3.readlines()
  print(file3_lines)
# Out:
# ['amount,duration,rate,down_payment\n', '883000,16,0.14,\n', '45230,48,0.07,4300\n', '100000,12,0.1,\n', '728400,120,0.12,100000\n', '3637400,240,0.06,\n', '82900,90,0.07,8900\n', '316000,16,0.13,\n', '15230,48,0.08,4300\n', '991360,99,0.08,\n', '323000,27,0.09,47200\n', '10000,36,0.08,20000\n', '528400,120,0.11,100000\n', '8633400,240,0.06,\n', '12900,90,0.08,8900\n']

# %%
file3_lines
# Out:
# ['amount,duration,rate,down_payment\n',
#  '883000,16,0.14,\n',
#  '45230,48,0.07,4300\n',
#  '100000,12,0.1,\n',
#  '728400,120,0.12,100000\n',
#  '3637400,240,0.06,\n',
#  '82900,90,0.07,8900\n',
#  '316000,16,0.13,\n',
#  '15230,48,0.08,4300\n',
#  '991360,99,0.08,\n',
#  '323000,27,0.09,47200\n',
#  '10000,36,0.08,20000\n',
#  '528400,120,0.11,100000\n',
#  '8633400,240,0.06,\n',
#  '12900,90,0.08,8900\n']

# %%
file3_lines[0].strip()#becuse os strip space and and new line ht gye
# Out:
# 'amount,duration,rate,down_payment'

# %% [markdown]
# #**Processing** data from file
#
# Before performing any operations on the data stored in a file, we need to convert the contents of the file from one large string into Python data types. For the file loans1.txt containing information about loans in a CSV format, we can do the following:
#
# Read the file line by line
#
# Parse the first line to get list of the column names or headers
#
# Split each remaining line and convert each value into a float
#
# Create a dictionary for each loan using the headers as keys
#
# Create a list of dictionaries to keep track of all the loans
#
#
#
#
# Since we will perform the same operations for multiple files, it would be useful define a function read_csv to do this. We'll also define some helper functions to build up the functionality step by step.
#
# Let's start by defining a function parse_header which takes a line as input and returns a list of column headers.

# %%
def parse_headers(header_line):
  return header_line.strip().split(',')

# %% [markdown]
# The strip method removes any extra spaces and the newline charcter \n,and the split method breaks a stringg into a list using the given separator (,in thos case)

# %%
file3_lines[0]
# Out:
# 'amount,duration,rate,down_payment\n'

# %%
headers=parse_headers(file3_lines[0])

# %%
headers
# Out:
# ['amount', 'duration', 'rate', 'down_payment']

# %% [markdown]
# Next line define a function parse_value which takes a line conrtaining some data,and returns a list of floating point numbers

# %%
def parse_values(data_line):
  values=[]
  for item in data_line.strip().split(','):
    values.append(float(item))
  return values

# %%
file3_lines[1]
# Out:
# '883000,16,0.14,\n'

# %%
'883000,16,0.14,\n'.strip().split(',')
# Out:
# ['883000', '16', '0.14', '']

# %%
parse_values(file3_lines[2])
# Out:
# [45230.0, 48.0, 0.07, 4300.0]

# %% [markdown]
# The values wee parsed and converted to floating point number as excepted.Lets it for another line from the file ,which does not contain a value for the down payment

# %%
file3_lines[1]
# Out:
# '883000,16,0.14,\n'

# %%
#parse_values(file3_lines[1])

# %% [markdown]
# This leads to ValuError beacuse the empty string cannot be converted to float.We can enheance the parse_value function to handle
# this edge case

# %% [markdown]
# " " cannot be converted into a float.we can enhance the parse_values functions to handles this edge case.

# %%
def parse_values(data_line):
  values=[]
  for item in data_line.strip().split(','):
    if item=='':
      values.append(0.0)
    else:
      values.append(float(item))
  return values

# %%
file3_lines[1]
# Out:
# '883000,16,0.14,\n'

# %%
parse_values(file3_lines[1])
# Out:
# [883000.0, 16.0, 0.14, 0.0]

# %% [markdown]
# Next, let's define a function create_item_dict which takes a list of values and a list of headers as inputs, and returns a dictionary with the values associated with their respective headers as keys.

# %%
def create_item_dict(values,headers):
  result={}
  for value,header in zip(values,headers):
    result[header]=value
  return result

# %%
for item in zip([1,2,3],['a','b','c']):
  print(item)
# Out:
# (1, 'a')
# (2, 'b')
# (3, 'c')

# %% [markdown]
# Let's try out create_item_dict with couple of example

# %%
file3_lines[2]
# Out:
# '45230,48,0.07,4300\n'

# %%
values1=parse_values(file3_lines[2])

# %%
values1
# Out:
# [45230.0, 48.0, 0.07, 4300.0]

# %%
headers
# Out:
# ['amount', 'duration', 'rate', 'down_payment']

# %%
create_item_dict(values1,headers)
# Out:
# {'amount': 45230.0, 'duration': 48.0, 'rate': 0.07, 'down_payment': 4300.0}

# %%
file3_lines[1]
# Out:
# '883000,16,0.14,\n'

# %%
values2=parse_values(file3_lines[1])
create_item_dict(values2,headers)
# Out:
# {'amount': 883000.0, 'duration': 16.0, 'rate': 0.14, 'down_payment': 0.0}

# %%
def read_csv(file_path):
  #open the file in read mode
  with open(file_path, 'r') as f:
    #get a list of lines
    lines = f.readlines()
    #parse the header
  headers = parse_headers(lines[0])
  #Loop over the reamaining lines
  data = []
  #Loop over the remaining lines
  for data_line in lines[1:]:
    #parse the values
    values = parse_values(data_line)
    #create a dictionary using values &Headers
    item_dict = create_item_dict(values, headers)
    #Add the dict to the result
    data.append(item_dict)
  return data

loans3_data = read_csv('./data/loans3.txt')

loans3_data[:5] # Display the first 5 entries
# Out:
# [{'amount': 883000.0, 'duration': 16.0, 'rate': 0.14, 'down_payment': 0.0},
#  {'amount': 45230.0, 'duration': 48.0, 'rate': 0.07, 'down_payment': 4300.0},
#  {'amount': 100000.0, 'duration': 12.0, 'rate': 0.1, 'down_payment': 0.0},
#  {'amount': 728400.0,
#   'duration': 120.0,
#   'rate': 0.12,
#   'down_payment': 100000.0},
#  {'amount': 3637400.0, 'duration': 240.0, 'rate': 0.06, 'down_payment': 0.0}]

# %% [markdown]
# **Lets try it out!**

# %%
with open('./data/loans2.txt','r') as file2:
  print(file2.read())
# Out:
# amount,duration,rate,down_payment
# 828400,120,0.11,100000
# 4633400,240,0.06,
# 42900,90,0.08,8900
# 983000,16,0.14,
# 15230,48,0.07,4300

# %%
read_csv('./data/loans2.txt')
# Out:
# [{'amount': 828400.0,
#   'duration': 120.0,
#   'rate': 0.11,
#   'down_payment': 100000.0},
#  {'amount': 4633400.0, 'duration': 240.0, 'rate': 0.06, 'down_payment': 0.0},
#  {'amount': 42900.0, 'duration': 90.0, 'rate': 0.08, 'down_payment': 8900.0},
#  {'amount': 983000.0, 'duration': 16.0, 'rate': 0.14, 'down_payment': 0.0},
#  {'amount': 15230.0, 'duration': 48.0, 'rate': 0.07, 'down_payment': 4300.0}]

# %% [markdown]
# *The* file is read and converted to a list of dictionaries, as expected. The read_csv file is generic enough that it can parse any file in the CSV format, with any number of rows or columns. Here's the full code for read_csv along with the helper functions:

# %%
def parse_headers(header_line):
  return header_line.strip().split(',')
def parse_values(data_line):
  values=[]
  for item in data_line.strip().split(','):
    if item=='':
      values.append(0.0)
    else:
      values.append(float(item))
  return values

def create_item_dict(values,headers):
  result={}
  for value,header in zip(values,headers):
    result[header]=value
  return result


def read_csv(file_path):
  result=[]
  #open the file in read mode
  with open(file_path,'r')as f:
    #get a list of lines

    lines=f.readlines()
    #parse the header
    headers=parse_headers(lines[0])
    #Loop over the reamaining lines
    for data_line in lines[1:]:
      #parse the values
      values=parse_values(data_line)
      #create a dict using val and head
      item_dict=create_item_dict(values,headers)
      #add the dict to the result

      result.append(item_dict)
  return result

# %%
import math

# %%
def loan_emi(amount,duration,rate,down_pay=0):
  """Calulates the eqaul monthly installment(emi)for a loan.

  Arguments:
    amount-total amount to be spent (loan + down payment)
    duration-duration of the loan (in months)
    rate-rate of interest (monthly)
    down_pay-intial payment required to start the loan (optional)

  """
  loan_amount = amount - down_pay
  try:
    emi = loan_amount * rate * ((1+rate)**duration) / (((1+rate)**duration)-1)
  except ZeroDivisionError:
    emi = loan_amount / duration
  emi=math.ceil(emi)
  return emi

# %% [markdown]
# WE can use this function to calculate EMIs for all the loans in a life

# %%
loans2=read_csv('./data/loans2.txt')

# %%
loans2
# Out:
# [{'amount': 828400.0,
#   'duration': 120.0,
#   'rate': 0.11,
#   'down_payment': 100000.0},
#  {'amount': 4633400.0, 'duration': 240.0, 'rate': 0.06, 'down_payment': 0.0},
#  {'amount': 42900.0, 'duration': 90.0, 'rate': 0.08, 'down_payment': 8900.0},
#  {'amount': 983000.0, 'duration': 16.0, 'rate': 0.14, 'down_payment': 0.0},
#  {'amount': 15230.0, 'duration': 48.0, 'rate': 0.07, 'down_payment': 4300.0}]

# %%
for loan in loans2:
  loan['emi']=loan_emi(loan['amount'],
                       loan['duration'],
                       loan['rate']/12,
                       loan['down_payment'])

# %%
loans2
# Out:
# [{'amount': 828400.0,
#   'duration': 120.0,
#   'rate': 0.11,
#   'down_payment': 100000.0,
#   'emi': 10034},
#  {'amount': 4633400.0,
#   'duration': 240.0,
#   'rate': 0.06,
#   'down_payment': 0.0,
#   'emi': 33196},
#  {'amount': 42900.0,
#   'duration': 90.0,
#   'rate': 0.08,
#   'down_payment': 8900.0,
#   'emi': 504},
#  {'amount': 983000.0,
#   'duration': 16.0,
#   'rate': 0.14,
#   'down_payment': 0.0,
#   'emi': 67707},
#  {'amount': 15230.0,
#   'duration': 48.0,
#   'rate': 0.07,
#   'down_payment': 4300.0,
#   'emi': 262}]

# %%
def computer_emis(loans2):
  for loan in loans2:
    loan['emi']=loan_emi(loan['amount'],
                       loan['duration'],
                       loan['rate']/12,
                       loan['down_payment'])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
loans2=read_csv('./data/loans2.txt')

# %%
computer_emis(loans2)

# %%
loans2
# Out:
# [{'amount': 828400.0,
#   'duration': 120.0,
#   'rate': 0.11,
#   'down_payment': 100000.0,
#   'emi': 10034},
#  {'amount': 4633400.0,
#   'duration': 240.0,
#   'rate': 0.06,
#   'down_payment': 0.0,
#   'emi': 33196},
#  {'amount': 42900.0,
#   'duration': 90.0,
#   'rate': 0.08,
#   'down_payment': 8900.0,
#   'emi': 504},
#  {'amount': 983000.0,
#   'duration': 16.0,
#   'rate': 0.14,
#   'down_payment': 0.0,
#   'emi': 67707},
#  {'amount': 15230.0,
#   'duration': 48.0,
#   'rate': 0.07,
#   'down_payment': 4300.0,
#   'emi': 262}]

# %%
with open('./data/emis2.txt','w') as f:
  for loan in loans2:
    f.write('{},{},{},{},{}\n'.format(
        loan['amount'],
        loan['duration'],
        loan['rate'],
        loan['down_payment'],
        loan['emi']))

# %% [markdown]
# Lets varify that the file was created and written to as expexted

# %%
os.listdir('data')
# Out:
# ['loans1.txt', 'loans2.txt', 'emis2.txt', 'loans3.txt']

# %%
with open('./data/emis2.txt','r') as f:
  print(f.read())
# Out:
# 828400.0,120.0,0.11,100000.0,10034
# 4633400.0,240.0,0.06,0.0,33196
# 42900.0,90.0,0.08,8900.0,504
# 983000.0,16.0,0.14,0.0,67707
# 15230.0,48.0,0.07,4300.0,262

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
loans2
# Out:
# [{'amount': 828400.0,
#   'duration': 120.0,
#   'rate': 0.11,
#   'down_payment': 100000.0,
#   'emi': 10034},
#  {'amount': 4633400.0,
#   'duration': 240.0,
#   'rate': 0.06,
#   'down_payment': 0.0,
#   'emi': 33196},
#  {'amount': 42900.0,
#   'duration': 90.0,
#   'rate': 0.08,
#   'down_payment': 8900.0,
#   'emi': 504},
#  {'amount': 983000.0,
#   'duration': 16.0,
#   'rate': 0.14,
#   'down_payment': 0.0,
#   'emi': 67707},
#  {'amount': 15230.0,
#   'duration': 48.0,
#   'rate': 0.07,
#   'down_payment': 4300.0,
#   'emi': 262}]

# %%
loans2[0]
# Out:
# {'amount': 828400.0,
#  'duration': 120.0,
#  'rate': 0.11,
#  'down_payment': 100000.0,
#  'emi': 10034}

# %%
list(loans2[0].keys())
# Out:
# ['amount', 'duration', 'rate', 'down_payment', 'emi']

# %%
#using join
','.join(list(loans2[0].keys()))
# Out:
# 'amount,duration,rate,down_payment,emi'

# %%
def write_csv(items,path):
  #open the file in write mode
  with open(path,'w') as f:
    #return if there nothing to write
    if len(items)==0:
      return

    #write headers in the first line
    headers = items[0].keys()
    f.write(','.join(headers)+'\n')

    #write one item per line
    for item in items:
      values = []
      for header in headers:
        values.append(str(item.get(header,"")))

      f.write(','.join(values)+"\n")

# %%
loans3=read_csv('./data/loans3.txt')

# %%
computer_emis(loans3)

# %%
write_csv(loans3,'./data/emis3.taxt')

# %%
with open('./data/emis3.taxt','r') as f:
  print(f.read())
# Out:
# amount,duration,rate,down_payment,emi
# 883000.0,16.0,0.14,0.0,60819
# 45230.0,48.0,0.07,4300.0,981
# 100000.0,12.0,0.1,0.0,8792
# 728400.0,120.0,0.12,100000.0,9016
# 3637400.0,240.0,0.06,0.0,26060
# 82900.0,90.0,0.07,8900.0,1060
# 316000.0,16.0,0.13,0.0,21618
# 15230.0,48.0,0.08,4300.0,267
# 991360.0,99.0,0.08,0.0,13712
# 323000.0,27.0,0.09,47200.0,11323
# 10000.0,36.0,0.08,20000.0,-313
# 528400.0,120.0,0.11,100000.0,5902
# 8633400.0,240.0,0.06,0.0,61853
# 12900.0,90.0,0.08,8900.0,60

# %% [markdown]
# With just 4 line of code we read each doinoad file,claulate the emis,write the result back in new files

# %%
for i in range(1,4):
  loans=read_csv('./data/loans{}.txt'.format(i))
  computer_emis(loans)
  write_csv(loans,'./data/emis{}.txt'.format(i))

# %%
os.listdir('./data')
# Out:
# ['loans1.txt',
#  'emis3.txt',
#  'loans2.txt',
#  'emis3.taxt',
#  'emis2.txt',
#  'loans3.txt',
#  'emis1.txt']

# %% [markdown]
# ![image.png](data:image/png;base64,...)
