# %% [markdown]
# Exercise: Try finding the percentage of responses from English-speaking vs. non-English speaking countries. You can use this list of languages spoken in different countries.

# %%
from urllib.request import urlretrieve

# %%
lang_spoken_url='https://raw.githubusercontent.com/JovianHQ/opendatasets/refs/heads/master/data/countries-languages-spoken/countries-languages.csv'
urlretrieve(lang_spoken_url, 'countries-languages.csv')
# Out:
# ('countries-languages.csv', <http.client.HTTPMessage at 0x793c99fb97c0>)

# %%
import pandas as pd

# %%
lang_spoken_df=pd.read_csv('countries-languages.csv')

# %%
lang_spoken_df
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                            Andorra
# 4                             Angola
# ..                               ...
# 193                          Vietnam
# 194  Western Sahara (proposed state)
# 195                            Yemen
# 196                           Zambia
# 197                         Zimbabwe
#
#                                       Languages Spoken
# 0    Dari Persian, Pashtu (both official), other Tu...
# 1       Albanian (Tosk is the official dialect), Greek
# 2           Arabic (official), French, Berber dialects
# 3    Catalán (official), French, Castilian, Portuguese
# 4    Portuguese (official), Bantu and other African...
# ..                                                 ...
# 193  Vietnamese (official); English (increasingly f...
# 194                  Hassaniya Arabic, Moroccan Arabic
# ...

# %%
type(lang_spoken_df)
# Out:
# pandas.core.frame.DataFrame

# %%
lang_spoken_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           198 non-null    object
#  1   Languages Spoken  198 non-null    object
# dtypes: object(2)
# memory usage: 3.2+ KB

# %%
lang_spoken_df['English_speaking']=lang_spoken_df['Languages Spoken'].str.contains('English',case=False,na=False)

# %%
lang_spoken_df
# Out:
#                              Country  \
# 0                        Afghanistan
# 1                            Albania
# 2                            Algeria
# 3                            Andorra
# 4                             Angola
# ..                               ...
# 193                          Vietnam
# 194  Western Sahara (proposed state)
# 195                            Yemen
# 196                           Zambia
# 197                         Zimbabwe
#
#                                       Languages Spoken  English_speaking
# 0    Dari Persian, Pashtu (both official), other Tu...             False
# 1       Albanian (Tosk is the official dialect), Greek             False
# 2           Arabic (official), French, Berber dialects             False
# 3    Catalán (official), French, Castilian, Portuguese             False
# 4    Portuguese (official), Bantu and other African...             False
# ..                                                 ...               ...
# ...

# %%
english_speaking_counts=lang_spoken_df['English_speaking'].value_counts()

# %%
print("counts:\n",counts)
# Out:
# counts:
#  Languages Spoken
# Spanish                                                                                                                                                               4
# English                                                                                                                                                               2
# English (official), French patois                                                                                                                                     2
# Arabic (official), English                                                                                                                                            2
# Arabic                                                                                                                                                                2
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(6,5))
sns.barplot(x=english_speaking_counts.index.map({True:"English-speaking",False:"Non-English Speaking"}),y=english_speaking_counts.values)
plt.title("Number of English vs Non-English Speaking Countries")
plt.ylabel("Number of Countries")
plt.xlabel("Category")
plt.show()

# %%
# 6) Optional: save to file
plt.savefig("english_vs_nonenglish_countries.png")

# %%
total = len(lang_spoken_df)
english =english_speaking_counts[True]
non_english = english_speaking_counts[False]

print(f"English-speaking: {english/total*100:.1f}%")
print(f"Non-English: {non_english/total*100:.1f}%")
# Out:
# English-speaking: 48.5%
# Non-English: 51.5%
